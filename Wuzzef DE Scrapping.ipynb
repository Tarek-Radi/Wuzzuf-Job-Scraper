# %%
# Liberaries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import csv

# %%
url = "https://wuzzuf.net/search/jobs?a=spbg&q=data%20engineer"

headers = {
    "User-Agent": "Mozilla/5.0"
}

# %%
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html data-id="SSR" dir="ltr" lang="en" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <meta content="notranslate" name="googlebot"/>
# <title data-rh="true">436 data engineer jobs in Egypt – discover job details now on Wuzzuf!</title>
# <meta charset="utf-8" data-rh="true"><meta content="Explore 436 data engineer jobs in Egypt.  Apply for great job opportunities in leading companies with Wuzzuf today!" data-rh="true" name="description"><meta content="jobs in Egypt, job in Egypt, careers egypt, jobs in Cairo, jobs in alexandria, employment in egypt, Egypt jobs, jobs vacancies, job vacancies in egypt, job search egypt, job vacancies egypt, job recruitment in egypt, job opportunities in egypt, jobs cairo, job vacancy egypt , وظائف مصر" data-rh="true" name="keywords"><meta content="en_EG" data-rh="true" property="og:locale"><meta content="436 data engineer jobs in Egypt – discover job details now on Wuzzuf!" data-rh="true" property="og:title"><meta content="website" data-rh="true" property="og:type"/><meta content="https://wuzzuf.net/search/jobs" data-rh="true" property="og:url"/><meta content="WUZZUF" data-rh="true" property="og:site_name"/><meta content="373086796047717" data-rh="true" property="fb:app_id"/><meta content="https://static.wuzzuf-data.net/search-page-og-image-bc0a066d44969c0f879dc5df1a6453f3.png" data-rh="true" property="og:image"/><meta content="Explore 436 data engineer jobs in Egypt.  Apply for great job opportunities in leading companies with Wuzzuf today!" data-rh="true" property="og:description"/><meta content="Maadi" data-rh="true" property="og:locality"/><meta content="Cairo" data-rh="true" property="og:region"/><meta content="Egypt" data-rh="true" property="og:country-name"/>
# <link data-rh="true" href="https://wuzzuf.net/search/jobs" rel="canonical"/><link data-rh="true" href="https://wuzzuf.net/search/jobs" hreflang="en-EG" rel="alternate"/><link data-rh="true" href="https://wuzzuf.net/ar/search/jobs" hreflang="ar-EG" rel="alternate"/><link data-rh="true" href="https://wuzzuf.net/search/jobs" hreflang="x-default" rel="alternate"/><link data-rh="true" href="https://wuzzuf.net/search/jobs?q=data%20engineer&amp;start=1" rel="next"/><link data-rh="true" href="https://wuzzuf.net/search/jobs" hreflang="en-EG" rel="alternate"/><link data-rh="true" href="https://wuzzuf.net/saudi/search/jobs" hreflang="en-SA" rel="alternate"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="https://wuzzuf.net/favicon.ico" rel="icon"/>
# <link as="script" data-chunk="index" href="https://static.wuzzuf-data.net/vendor-1776172333969.ed4d102a526ee583fb62.js" rel="preload"/>
# <link as="script" data-chunk="index" href="https://static.wuzzuf-data.net/index-1776172333969.e12a64ca732efde15f45.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/8471-1776172333969.6f44d0965670bfa48f42.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/6534-1776172333969.59e4e459adf8bafeda1e.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/6891-1776172333969.f7c8fba9aa359ab474b9.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/3617-1776172333969.b64ed7d22a77a943e299.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/9503-1776172333969.77877dde969015c5adcb.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/9237-1776172333969.dd6abff374ff51cd3e71.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/6902-1776172333969.5ee9765c0c880cfb2293.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/127-1776172333969.df22028cf206e11145d3.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/8773-1776172333969.7043d85887d40544cc56.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/guest-footer-1776172333969.2958eb36fd270c396bb1.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/app-not-found-1776172333969.fcd2340f969d83f4f51f.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/1351-1776172333969.7d295fff0464143b040f.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/7609-1776172333969.3fe0ffefdec2deea6132.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/643-1776172333969.ea3b1659703f49687e8b.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/1476-1776172333969.824330db405cf6d1acdb.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/1879-1776172333969.d774bd9e979eb013a02f.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/guest-job-search-1776172333969.80f2e80e59f01f282089.js" rel="preload"/>
# <link as="script" data-chunk="job-search-components-job-search-page-search-bar-card-desktop" href="https://static.wuzzuf-data.net/3736-1776172333969.cb55138451d5dc99860e.js" rel="preload"/>
# <link as="script" data-chunk="job-search-components-job-search-page-search-bar-card-desktop" href="https://static.wuzzuf-data.net/368-1776172333969.3136a082c3ac1c48f12d.js" rel="preload"/>
# <link as="script" data-chunk="job-search-components-job-search-page-search-bar-card-desktop" href="https://static.wuzzuf-data.net/3193-1776172333969.7c119f00190f9e068827.js" rel="preload"/>
# <link as="script" data-chunk="job-search-components-job-search-page-search-bar-card-desktop" href="https://static.wuzzuf-data.net/job-search-components-job-search-page-search-bar-card-desktop-1776172333969.b497f981fc8c9b2f76de.js" rel="preload"/>
# <link as="style" href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i&amp;display=swap" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <link as="style" href="https://fonts.googleapis.com/css2?family=IBM+Plex+Sans+Arabic:wght@300;400;600;700&amp;display=swap" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <noscript>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=IBM+Plex+Sans+Arabic:wght@300;400;600;700&amp;display=swap" rel="stylesheet"/>
# </noscript>
# <style>
#         html, body {
#             padding: 0;
#             margin: 0;
#             font-family: 'Open Sans', sans-serif;
#         }
#
#         input, textarea, select, button {
#             font-family: 'Open Sans', sans-serif;
#         }
#
#         /* Apply IBM Plex Sans Arabic when document is RTL */
#         html[dir="rtl"], html[dir="rtl"] body,
#         html[dir="rtl"] input, html[dir="rtl"] textarea,
#         html[dir="rtl"] select, html[dir="rtl"] button, [dir="rtl"] {
#             font-family: 'IBM Plex Sans Arabic', 'Open Sans', sans-serif;
#         }
#
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         a {
#             text-decoration: none;
#             color: inherit;
#         }
#
#         @keyframes spin {
#             to { transform: rotate(360deg); }
#         }
#
#         .entry-loader {
#             z-index: 999999;
#             background: #fff;
#             position: fixed;
#             inset: 0;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             opacity: 1;
#             transition: opacity .6s ease-in-out;
#         }
#
#         .entry-loader.faded { opacity: 0; }
#
#         .entry-loader:after {
#             content: '';
#             border-radius: 50%;
#             width: 32px; height: 32px;
#             border: 4px solid #0055D9;
#             border-block-start-color: #fff;
#             animation: spin .8s linear infinite;
#         }
#     </style>
# <link href="https://static.wuzzuf-data.net/css/global.css" media="print" onload="this.onload=null;this.rel='stylesheet';this.media='all'" rel="stylesheet"/>
# <link href="https://static.wuzzuf-data.net/css/lib.css" media="print" onload="this.onload=null;this.rel='stylesheet';this.media='all'" rel="stylesheet" type="text/css"/>
# </meta></meta></meta></meta></meta></meta></head>
# <body>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-T4Z552" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div id="app"><div><style data-emotion="css 1jsz4vo">.css-1jsz4vo{height:62px;position:relative;}</style><div class="css-1jsz4vo"><style data-emotion="css osk6ex">.css-osk6ex{z-index:9998;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;height:62px;width:100%;position:fixed;top:var(--cx-banner-height, 0px);inset-inline:0;background-color:#ffffff;border-block-end:1px solid #D9DDE4;}</style><header class="css-osk6ex"><style data-emotion="css o6c8e1">.css-o6c8e1{width:100%;max-width:1170px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;padding-inline:10px;}</style><div class="css-o6c8e1"><style data-emotion="css gbex76">.css-gbex76{-webkit-margin-end:24px;margin-inline-end:24px;}</style><style data-emotion="css ayzvps">.css-ayzvps{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;position:relative;cursor:pointer;width:125px;-webkit-margin-end:24px;margin-inline-end:24px;}</style><a aria-label="navigate to wuzzuf home page" class="css-ayzvps e19qcx5a0" href="/jobs/egypt"><style data-emotion="css 1d3w5wq">.css-1d3w5wq{width:100%;}</style><svg aria-labelledby="wuzzuf-logo" class="css-1d3w5wq" viewbox="0 0 125 20" xmlns="http://www.w3.org/2000/svg"><path d="M23.724.001h4.906L22.583 20H18.17L14.315 7.96 10.489 20H6.046L0 .001h4.936L8.793 12.32 12.587 0h3.61l3.671 12.319L23.724 0zm9.147 17.552c-1.604-1.63-2.406-3.823-2.406-6.577V.001h4.689v11.036c0 1.54.432 2.714 1.296 3.524.864.81 2.046 1.215 3.548 1.215 1.48 0 2.648-.405 3.502-1.215.853-.81 1.28-1.985 1.28-3.524V0h4.689v10.975c0 2.754-.792 4.947-2.376 6.577C45.51 19.184 43.145 20 39.998 20s-5.523-.815-7.127-2.446zm18.416-.694L62.456 3.95H51.565V.001h16.69v3.17L57.15 16.052h11.106V20H51.287v-3.14zm18.803 0L81.258 3.95h-10.89V.001h16.69v3.17l-11.106 12.88h11.106v3.948H70.09v-3.14zm21.226.694c-1.605-1.63-2.407-3.823-2.407-6.577V.001h4.69v11.036c0 1.54.432 2.714 1.295 3.524.864.81 2.047 1.215 3.548 1.215 1.481 0 2.648-.405 3.502-1.215.853-.81 1.28-1.985 1.28-3.524V0h4.69v10.975c0 2.754-.793 4.947-2.376 6.577-1.584 1.631-3.949 2.446-7.096 2.446-3.147 0-5.522-.815-7.126-2.446zm23.279-5.733V20h-4.69V0H125l-1.08 3.982h-9.325V8.18h7.959l-.99 3.64h-6.97z" fill="#0055D9"></path></svg></a><div class="css-0"><style data-emotion="css 1rhi69u">.css-1rhi69u{font-size:15px;font-weight:600;-webkit-text-decoration:none;text-decoration:none;-webkit-margin-end:12px;margin-inline-end:12px;padding:12px;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#405678;}.css-1rhi69u:hover{color:#0055D9;}.css-1rhi69u:hover path{fill:#0055D9;}.css-1rhi69u:hover div{border-block-start:5px solid #0055D9;}</style><a class="css-1rhi69u" href="#">Browse Jobs<style data-emotion="css 2t2q4i">.css-2t2q4i{-webkit-margin-start:8px;margin-inline-start:8px;}</style><style data-emotion="css 7ba69u">.css-7ba69u{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;line-height:1em;width:16px;height:16px;-webkit-margin-start:8px;margin-inline-start:8px;}</style><i class="css-7ba69u efou2fk0" size="16"><svg height="16" preserveaspectratio="none" viewbox="0 0 24 24" width="16"><path d="M17.355 7.5L12 13.063 6.645 7.5 5 9.213l7 7.287 7-7.287z" fill="#334B6F"></path></svg></i></a></div><style data-emotion="css yujhzj">.css-yujhzj{-webkit-flex:2;-ms-flex:2;flex:2;display:-webkit-box;display:-webk ...
# <script>
#         (function(){
#             var Wuzzuf = window.Wuzzuf = window.Wuzzuf || {};
#             Wuzzuf.country = {"country":"Egypt","countryId":"","countryIso":"eg","subFolder":"","subFolderName":"egypt","jobseekerHomePage":"\u002Fjobs\u002Fegypt","empHomePage":"\u002Frecruitment\u002Fegypt","hrefLang":"en-EG","countryCurrency":"43","viewerCountryIso":"eg","isInternationalFlag":false};
#             Wuzzuf.headers = {"host":"wuzzuf.net","x-real-ip":"45.244.74.185","x-forwarded-for":"45.244.74.185, 45.244.74.185","x-forwarded-proto":"http","connection":"close","x-request-id":"3b144fdd54932511d1da9eac4052281d","x-forwarded-host":"wuzzuf.net","x-forwarded-port":"80","x-forwarded-scheme":"http","x-scheme":"http","x-original-forwarded-for":"45.244.74.185","x-amzn-trace-id":"Root=1-69e3b61b-28e0c452164a492825c05b75","cloudfront-viewer-asn":"13335","cloudfront-is-tablet-viewer":"false","cloudfront-is-mobile-viewer":"false","cloudfront-viewer-country":"FR","cf-ray":"9ee529cd1a7de244-MRS","user-agent":"Mozilla\u002F5.0","via":"2.0 dd239fa6f06e5b3ae1437460dbc3d6a6.cloudfront.net (CloudFront)","x-amz-cf-id":"e_w0JkGHhCe2MedX9WbXv21uxAoPsX7JVg4pZ2wmwHJ49gSZQGykDg==","cdn-loop":"cloudflare; loops=1, cloudfront","cf-connecting-ip":"45.244.74.185","cloudfront-is-desktop-viewer":"true","accept":"*\u002F*","accept-encoding":"gzip, br","cf-ipcountry":"EG","cf-visitor":"{\"scheme\":\"https\"}","cloudfront-forwarded-proto":"https","cloudfront-is-smarttv-viewer":"false"};
#             Wuzzuf.cookies = {};
#             Wuzzuf.isServerRendered = true;
#             Wuzzuf.initialStoreState = {"badges":{"landingPage":{"timestamp":null,"providers":null,"loading":false}},"browsingPage":{"sets":{},"metaTemplateType":{}},"communityPages":{"internship":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"alexandria":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"android":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"pharmaceutical":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"workFromHome":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"startups":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"multipleVacancies":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null}},"companyPage":{"sets":{}},"entities":{"companyPlanBenefit":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"applicationStatistics":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"badge":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"badgeGradeDetails":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"company":{"collection":{"362":{"id":"362","type":"company","attributes":{"uniqueId":"c6948f50-9373-11ea-add1-062a4819e772","name":"GB Corp","legalName":null,"logo":"32859703165841b38b4878.png","slug":"Ghabbour-Auto-Egypt-362","description":"Welcome to GB Corp, a leading local and regional powerhouse that capitalizes on market opportunities and expands its range of services and products through the transformative power of \"The Power of Mobility\". With a rich history spanning over 80 years, we initially started as Ghabbour, a family-owned enterprise. Throughout our journey, we have consistently maintained our position at the forefront of various industries and sectors by fostering innovation, empowering our workforce, and enabling access to independence and well-being. As the parent company\u002Fbrand, GB Corp oversees six major subsidiaries: GB Auto, GB Capital, GB Logistics, GB Ventures, GB Academy, and Ghabbour Foundation. Join us as we continue to drive growth and make a positive impact in the market.","specialties":[],"workIndustries":[{"id":12,"name":"Automotive","browsePage":"a\u002FAutomotive-Jobs-in-Egypt"},{"id":60,"name":"Logistics and Supply Chain","browsePage":"a\u002FLogistics-And-Supply-Chain-Jobs-in-Egypt"},{"id":63,"name":"Manufacturing","browsePage":"a\u002FManufacturing-Jobs-in-Egypt"}],"hiringFor":null,"website":"http:\u002F\u002Fwww.gb-corporation.com\u002F","facebookPage":"https:\u002F\u002Fwww.linkedin.com\u002Fcompany\u002Fgbcorpmea\u002F","twitterAccount":null,"linkedinProfile":"https:\u002F\u002Fwww.linkedin.com\u002Fcompany\u002Fgbcorpmea\u002F","blog":null,"onlinePresence":{"facebook":"https:\u002F\u002Fwww.linkedin.com\u002Fcompany\u002Fgbcorpmea\u002F","twitter":null,"linkedin":"https:\u002F\u002Fwww.linkedin.com\u002Fcompany\u002Fgbcorpmea\u002F","blog":null,"website":"http:\u002F\u002Fwww.gb-corporation.com\u002F","instagram":"https:\u002F\u002Finstagram.com\u002Fgbcorpmea?igshid=MzRlODBiNWFlZA==","youtube":null,"vimeo":null,"behance":null},"establishedYear":null,"uniqueName":"GB Corp -w- 362","taxId":null,"street":null,"isPersonal":false,"buildingNumber":null,"area":null,"publicStatus":{"id":1,"name":"Verified"},"statusUpdatedAt":null,"createdAt":"05\u002F22\u002F2012 21:17:26","perks":[{"id":1,"name":"medical insurance"},{"id":2,"name":"social insurance"},{"id":4,"name":"transportation coverage"},{"id":5,"name":"performance bonus"},{"id":6,"name":"maternity leave"},{"id":7,"name":"flexible hours"},{"id":8,"name":"work from home"},{"id":9,"name":"employee discounts"},{"id":12,"name":"family medical insurance"}]},"links":{"self":"https:\u002F\u002Fwuzzuf.net\u002Fapi\u002Fcompany\u002F362","defau ...
#             Wuzzuf.serverRenderedURL = "/search/jobs?a=spbg&q=data%20engineer";
#             Wuzzuf.userType = "guest";
#             Wuzzuf.initialI18nStore = {"en":{"job-page":{"company-badge":{"verified_company_tooltip":"This company is verified by WUZZUF","new_company":"New company","under_review_tooltip":"This job was posted by a new employer who is being verified as a normal process. Contact us if you\n                    notice there are any issues.","not_verified":"Not Verified","not_verified_tooltip":"This company is not verified by WUZZUF. It does not match our verification conditions"},"company-info":{"new":"NEW!","build_employer_brand":"Build your Employer Brand now on WUZZUF","about":"About","edit_company_page":"Edit Company Page","less":"Less","more":"More","company_link":"Browse all vacancies at {{companyName}}","company_logo_alt":"{{companyName}} logo"},"error-msg":{"message":"Something went wrong, please try again"},"job-browsing-actions":{"browse_similar":"Browse Similar {{jobType}}","search_other_opportunities":"Search other opportunities","opportunities":"Opportunities","jobs":"Jobs"},"job-insights":{"people_have_clicked":"People have clicked","open":"open","shared_time":"You shared your profile on the {{time}}","applicants":"Applicants -","applicants_for":"Applicants for","viewed":"Viewed","in_consideration":"In Consideration","not_selected":"Not Selected","open_positions_summary_one":"{{countFormatted}} open position","open_positions_summary_other":"{{countFormatted}} open positions"},"jobs-list":{"confidential_company":"Confidential Company","posted_from":"{{time}} ago","company_logo_alt":"{{companyName}} logo","company_logo_placeholder_alt":"Company buildings placeholder logo","featured_opportunities":"Featured opportunities","featured_jobs":"Featured Jobs","similar_opportunities":"Similar opportunities","similar_jobs":"Similar Jobs","search_other_new_internships":"Search other new internships","search_other_opportunities":"Search other opportunities"},"page-error-state":{"message":"Sorry, There has been an issue loading your data","reload":"Reload"},"related-jobs":{"find_related_opportunities":"Find Related opportunities","find_related_jobs":"Find Related Jobs","all_vacancies_at_company":"All vacancies at {{company}}","jobs_in_city":"{{title}} jobs in {{city}}","jobs_in_country":"{{title}} jobs in {{country}}","work_role_jobs_in_country":"{{workRole}} jobs in {{country}}","jobs_in":"Jobs in {{country}}","internships_in_egypt":"Internships in Egypt"},"job-details":{"index":{"details":"{{jobType}} Details","job_categories":"Job Categories:","skills_and_tools":"Skills And Tools:","internship":"Internship","event":"Event","job":"Job","fields.experience_needed":"Experience Needed","fields.career_level":"Career Level","fields.education_level":"Education Level","fields.gender":"Gender","fields.salary":"Salary","fields.job_categories":"Job Categories","fields.skills_and_tools":"Skills & Tools","see_less":"See Less","see_more":"See More"}},"job-main-card":{"closed-label":{"closed":"Closed","tooltip":"This job is no longer available to apply for"},"company-info-row":{"confidential_company":"Confidential Company","tooltip":"This company prefers to keep its name hidden"},"company-logo":{"img_alt":"{{companyName}} logo","placeholder_img_alt":"Company buildings placeholder logo"},"first-apply-text":{"be_the_first_to_apply":"Be the First to Apply"},"posted-from-date-in-words":{"posted_time":"posted {{time}} ago"}},"bread-crumb":{"internship":"Internship","job":"Job"},"community-page-banner":{"internships_img_title":"{{year}} Internships & Summer Training in Egypt"},"google-indexing":{"confidential_company_link":"N/A","confidential_company_name":"Confidential","internship_description":"Internship Description","job_description":"Job Description","internship_requirements":"Internship Requirements","job_requirements":"Job Requirements","salary_negotiable":"N/A"},"head-tags":{"job.hidden.title":"{{title}} vacancy in {{jobLocation}} | {{experienceNeeded}}","job.hidden.experience":"experience","job.hidden.description":"Apply for a {{workType}} ...
#             Wuzzuf.initialLanguage = "en";
#
#         }());
#     </script>
# <script>
#         window.addEventListener('beforeinstallprompt', function(){
#             e.preventDefault();
#         });
#     </script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[8471,6534,6891,3617,9503,9237,6902,127,8773,1943,2567,1351,7609,643,1476,1879,3220,3736,368,3193,3536]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["guest-job-search","job-search-components-job-search-page-search-bar-card-desktop"]}</script>
# <script data-chunk="index" defer="" src="https://static.wuzzuf-data.net/vendor-1776172333969.ed4d102a526ee583fb62.js"></script>
# <script data-chunk="index" defer="" src="https://static.wuzzuf-data.net/index-1776172333969.e12a64ca732efde15f45.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/8471-1776172333969.6f44d0965670bfa48f42.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/6534-1776172333969.59e4e459adf8bafeda1e.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/6891-1776172333969.f7c8fba9aa359ab474b9.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/3617-1776172333969.b64ed7d22a77a943e299.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/9503-1776172333969.77877dde969015c5adcb.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/9237-1776172333969.dd6abff374ff51cd3e71.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/6902-1776172333969.5ee9765c0c880cfb2293.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/127-1776172333969.df22028cf206e11145d3.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/8773-1776172333969.7043d85887d40544cc56.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/guest-footer-1776172333969.2958eb36fd270c396bb1.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/app-not-found-1776172333969.fcd2340f969d83f4f51f.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/1351-1776172333969.7d295fff0464143b040f.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/7609-1776172333969.3fe0ffefdec2deea6132.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/643-1776172333969.ea3b1659703f49687e8b.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/1476-1776172333969.824330db405cf6d1acdb.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/1879-1776172333969.d774bd9e979eb013a02f.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/guest-job-search-1776172333969.80f2e80e59f01f282089.js"></script>
# <script data-chunk="job-search-components-job-search-page-search-bar-card-desktop" defer="" src="https://static.wuzzuf-data.net/3736-1776172333969.cb55138451d5dc99860e.js"></script>
# <script data-chunk="job-search-components-job-search-page-search-bar-card-desktop" defer="" src="https://static.wuzzuf-data.net/368-1776172333969.3136a082c3ac1c48f12d.js"></script>
# <script data-chunk="job-search-components-job-search-page-search-bar-card-desktop" defer="" src="https://static.wuzzuf-data.net/3193-1776172333969.7c119f00190f9e068827.js"></script>
# <script data-chunk="job-search-components-job-search-page-search-bar-card-desktop" defer="" src="https://static.wuzzuf-data.net/job-search-components-job-search-page-search-bar-card-desktop-1776172333969.b497f981fc8c9b2f76de.js"></script>
# <script data-cf-beacon='{"token": "c0ca6af573dc4cd5973fdbdea3c92282"}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js"></script>
# </body>
# </html>

# %%
job_cards = soup.find_all("div", class_="css-pkv5jc")

# %%
jobs = []

#Select Every h2 and a inside it
title_links = soup.select("h2 a")
print(title_links)

# h2_tags = soup.find_all("h2")

# title_links = []
# for h2 in h2_tags:
#     a = h2.find("a")
#     if a:
#         title_links.append(a)

for link in title_links:
    title = link.get_text(" ", strip=True)
    href = link.get("href", "")
    job_link = "https://wuzzuf.net" + href if href.startswith("/") else href   #----because it was Exist in web 

    
    block = link.find_parent()

    
    parent_text = block.parent.get_text("\n", strip=True) if block and block.parent else ""
    # print(parent_text)
    # # Output :
    # # Middle Data Engineer
    # # Vertex Technologies  -
    # # Cairo,
    # # Egypt
    # # 3 days ago
    # # Senior Data Engineer
    
    lines = [line.strip() for line in parent_text.split("\n")]
    # print(lines)
    # Output ['Middle Data Engineer', 'Vertex Technologies  -', 'Cairo,', 'Egypt', '3 days ago']

    company = "N/A"
    city =    "N/A"
    country = "N/A"
    posted =  "N/A"

    if len(lines) > 0:
        title = lines[0]

    if len(lines) > 1:
        company = lines[1]

    if len(lines) > 2:
        city = lines[2]

    if len(lines) > 3:
        country = lines[3]

    if len(lines) > 4:
        posted = lines[4]

    jobs.append({
        "title": title,
        "company": company,
        "city": city,
        "country": country,
        "posted": posted,
        "link": job_link
    })

for job in jobs[:10]:
    print("Title   :", job["title"])
    print("Company :", job["company"])
    print("City    :", job["city"])
    print("Country :", job["country"])
    print("Posted  :", job["posted"])
    print("Link    :", job["link"])
    print("-" * 80)
# Out:
# [<a class="css-o171kl" href="/jobs/p/f3fi6wjnx9o9-middle-data-engineer-vertex-technologies-cairo-egypt" rel="noreferrer" target="_blank">Middle Data Engineer</a>, <a class="css-o171kl" href="/jobs/p/dw9vbculsh2b-senior-data-engineer-vertex-technologies-cairo-egypt" rel="noreferrer" target="_blank">Senior Data Engineer</a>, <a class="css-o171kl" href="/jobs/p/desxrlp7krfz-senior-data-engineer-gb-corp-giza-egypt" rel="noreferrer" target="_blank">Senior Data Engineer</a>, <a class="css-o171kl" href="/jobs/p/beqgj9o9kpfk-data-engineer-hyundai-rotem-cairo-egypt" rel="noreferrer" target="_blank">Data Engineer</a>, <a class="css-o171kl" href="/jobs/p/bitfhi15bemy-data-center-engineer-compute-storage-data-protection-cairo-egypt" rel="noreferrer" target="_blank">Data Center Engineer (Compute, Storage &amp; Data Protection)</a>, <a class="css-o171kl" href="/jobs/p/mc8ehc6xddfq-infrastructure-network-operations-engineer-data-center-wan-cairo-egypt" rel="noreferrer" target="_blank">Infrastructure Network Operations Engineer (Data Center &amp; WAN)</a>, <a class="css-o171kl" href="/jobs/p/x8tb3ijdep9x-senior-sales-engineer-data-centers-mission-critical-infrastructure-mobi-egypt-cairo-egypt" rel="noreferrer" target="_blank">Senior Sales Engineer – Data Centers &amp; Mission-Critical Infrastructure</a>, <a class="css-o171kl" href="/jobs/p/bl1q5hs5faeq-bi-engineer-sql-python-riseup-endemag-for-administrative-skills-development-cairo-egypt" rel="noreferrer" target="_blank">BI Engineer - SQL / PYTHON</a>, <a class="css-o171kl" href="/jobs/p/s7uloeeg1qxy-qs-engineer-concrete-plus-cairo-egypt" rel="noreferrer" target="_blank">QS Engineer</a>, <a class="css-o171kl" href="/jobs/p/oi2e0hcm9gmc-senior-electrical-procurement-engineer-concrete-plus-cairo-egypt" rel="noreferrer" target="_blank">Senior Electrical Procurement Engineer</a>, <a class="css-o171kl" href="/jobs/p/hnqrkmq9lp3n-production-engineer-el-rashidi-el-mizan-giza-egypt" rel="noreferrer" target="_blank">Production Engineer</a>, <a class="css-o171kl" href="/jobs/p/zl1tlcwdq9wm-senior-storage-and-backup-engineer-anzemah-giza-egypt" rel="noreferrer" target="_blank">Senior Storage and Backup Engineer</a>, <a class="css-o171kl" href="/jobs/p/laprqjalr4h6-senior-security-engineer-security-team-lead-anzemah-giza-egypt" rel="noreferrer" target="_blank">Senior Security Engineer / Security Team Lead</a>, <a class="css-o171kl" href="/jobs/p/hif824t4axxr-data-scientist-and-machine-learning-engineer-applied-ai-knowledge-sharing-epsilonai-cairo-egypt" rel="noreferrer" target="_blank">Data Scientist And Machine learning Engineer - Applied AI &amp; Knowledge Sharing</a>, <a class="css-o171kl" href="/jobs/p/wobpk6dqvtvq-cost-estimation-engineer-procurement-aswaq-cairo-egypt" rel="noreferrer" target="_blank">Cost Estimation Engineer (procurement)</a>]
# Title   : Middle Data Engineer
# Company : Vertex Technologies  -
# City    : Cairo,
# Country : Egypt
# Posted  : 3 days ago
# Link    : https://wuzzuf.net/jobs/p/f3fi6wjnx9o9-middle-data-engineer-vertex-technologies-cairo-egypt
# --------------------------------------------------------------------------------
# Title   : Senior Data Engineer
# Company : Vertex Technologies  -
# City    : Cairo,
# Country : Egypt
# Posted  : 3 days ago
# Link    : https://wuzzuf.net/jobs/p/dw9vbculsh2b-senior-data-engineer-vertex-technologies-cairo-egypt
# --------------------------------------------------------------------------------
# Title   : Senior Data Engineer
# Company : GB Corp -
# City    : Giza,
# Country : Egypt
# Posted  : 2 days ago
# Link    : https://wuzzuf.net/jobs/p/desxrlp7krfz-senior-data-engineer-gb-corp-giza-egypt
# --------------------------------------------------------------------------------
# Title   : Data Engineer
# Company : Hyundai Rotem -
# City    : Cairo,
# Country : Egypt
# Posted  : 20 days ago
# Link    : https://wuzzuf.net/jobs/p/beqgj9o9kpfk-data-engineer-hyundai-rotem-cairo-egypt
# --------------------------------------------------------------------------------
# Title   : Data Center Engineer (Compute, Storage & Data Protection)
# Company : Confidential -
# City    : New Capital,
# Country : Cairo,
# Posted  : Egypt
# Link    : https://wuzzuf.net/jobs/p/bitfhi15bemy-data-center-engineer-compute-storage-data-protection-cairo-egypt
# --------------------------------------------------------------------------------
# Title   : Infrastructure Network Operations Engineer (Data Center & WAN)
# Company : Confidential -
# City    : New Capital,
# Country : Cairo,
# Posted  : Egypt
# Link    : https://wuzzuf.net/jobs/p/mc8ehc6xddfq-infrastructure-network-operations-engineer-data-center-wan-cairo-egypt
# --------------------------------------------------------------------------------
# Title   : Senior Sales Engineer – Data Centers & Mission-Critical Infrastructure
# Company : Mobi Egypt -
# City    : Maadi,
# Country : Cairo,
# Posted  : Egypt
# Link    : https://wuzzuf.net/jobs/p/x8tb3ijdep9x-senior-sales-engineer-data-centers-mission-critical-infrastructure-mobi-egypt-cairo-egypt
# --------------------------------------------------------------------------------
# Title   : BI Engineer - SQL / PYTHON
# Company : RISEUP (Endemag for Administrative Skills Development) -
# City    : Maadi,
# Country : Cairo,
# Posted  : Egypt
# Link    : https://wuzzuf.net/jobs/p/bl1q5hs5faeq-bi-engineer-sql-python-riseup-endemag-for-administrative-skills-development-cairo-egypt
# --------------------------------------------------------------------------------
# Title   : QS Engineer
# Company : Concrete Plus -
# City    : Cairo,
# Country : Egypt
# Posted  : 2 days ago
# Link    : https://wuzzuf.net/jobs/p/s7uloeeg1qxy-qs-engineer-concrete-plus-cairo-egypt
# --------------------------------------------------------------------------------
# Title   : Senior Electrical Procurement Engineer
# Company : Concrete Plus -
# City    : New Cairo,
# Country : Cairo,
# Posted  : Egypt
# Link    : https://wuzzuf.net/jobs/p/oi2e0hcm9gmc-senior-electrical-procurement-engineer-concrete-plus-cairo-egypt
# --------------------------------------------------------------------------------
